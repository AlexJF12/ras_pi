# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
url = 'https://gutenberg.ca/ebooks/hemingwaye-oldmanandthesea/hemingwaye-oldmanandthesea-00-h.html'
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
clean_p = [p.get_text() for p in soup.findAll('p')]

# %%
def chunk_p(para, max_chunk_size):
    """Takes a string, returns multiple strings of under 270 char each"""
    
    chunk = []
    list_of_chunks = []
    chunk_char_length = 0
    words_in_para = para.split()
    
    if len(para) < max_chunk_size:
        return [para]

    for n, w in enumerate(para.split()):
        chunk.append(w)
        chunk_char_length += (len(w) + 1)

        if chunk_char_length > max_chunk_size - 5:
            list_of_chunks.append(chunk)
            chunk = []
            chunk_char_length = 0
            continue

        elif n + 1 == len(words_in_para):
            list_of_chunks.append(chunk)

        else:
            pass
    
    chunked = [' '.join(c) for c in list_of_chunks]
    
    return chunked

# %%
# dataframe by paragraph
df = pd.DataFrame({'text': clean_p})
df['text'] = df['text'].str.strip('\n')
df['char_count'] = df['text'].str.len()
df['over_twitter_length'] = df['char_count'] > 280
df['p_num'] = df.index

# %%
# chunk text string to smaller sizes
df['text_chunked'] = df['text'].apply(chunk_p, max_chunk_size = 220).to_list()
# count chunks in each
df['chunk_tot'] = [len(l) for l in df['text_chunked']]
# expand each element in chunk column to its own row, join back to original row's data
df = df.explode('text_chunked')
# add chunk number in paragraph
df['chunk_num'] = df.groupby(['p_num']).cumcount()+1
# reset index
df.reset_index(inplace=True, drop=True)
# add x/n for threads and hashtag
text_to_tweet = []
for text, chunk_num, chunk_tot in zip(df['text_chunked'], df['chunk_num'], df['chunk_tot']):
    if chunk_tot > 1:
        text_to_tweet.append(f'{text} {chunk_num}/{chunk_tot} #hemingway')
    else:
        text_to_tweet.append(f'{text} \n\n#hemingway')
df['text_to_tweet'] = text_to_tweet
# char count of text_to_tweet
df['text_to_tweet_char_count'] = df['text_to_tweet'].str.len()
# timestamp of tweet
df['tweeted_timestamp'] = ''

# %%
df.to_csv('data/old_man_and_the_sea.csv', index=False)
# only run the ts version once, could overwrite the ts list
df.to_csv('data/old_man_and_the_sea_timestamps.csv', index=False)

# %%
df.head(50)
# Out:
#                                                  text  char_count  \
# 0                                    ERNEST HEMINGWAY          16
# 1           CHARLES SCRIBNER'S SONS, NEW YORK\n\n1952          39
# 2   COPYRIGHT, 1952, BY\n\nERNEST HEMINGWAY\n\nPri...         203
# 3        TO CHARLIE SCRIBNER\n\nAND\n\nTO MAX PERKINS          40
# 4                                                               0
# 5                             THE OLD MAN AND THE SEA          23
# 6   He was an old man who fished alone in a skiff ...         742
# 7   He was an old man who fished alone in a skiff ...         742
# 8   He was an old man who fished alone in a skiff ...         742
# 9   He was an old man who fished alone in a skiff ...         742
# 10  The old man was thin and gaunt with deep wrink...         416
# 11  The old man was thin and gaunt with deep wrink...         416
# 12  Everything about him was old except his eyes a...         118
# 13  "Santiago," the boy said to him as they climbe...         146
# 14  The old man had taught the boy to fish and the...          61
# 15  "No," the old man said.  "You're with a lucky ...          69
# 16  "But remember how you went eighty-seven days w...         113
# 17  "I remember," the old man said.  "I know you d...          83
# 18  "It was papa made me leave.  I am a boy and I ...          61
# 19  "I know," the old man said.  "It is quite norm...          50
# 20                            "He hasn't much faith."          23
# 21  "No," the old man said.  "But we have.  Haven'...          52
# 22  "Yes," the boy said.  "Can I offer you a beer ...          97
# 23  "Why not?" the old man said.  "Between fisherm...          50
# 24  They sat on the Terrace and many of the fisher...         867
# 25  They sat on the Terrace and many of the fisher...         867
# 26  They sat on the Terrace and many of the fisher...         867
# 27  They sat on the Terrace and many of the fisher...         867
# 28  When the wind was in the east a smell came acr...         248
# 29  When the wind was in the east a smell came acr...         248
# 30                          "Santiago," the boy said.          25
# 31  "Yes," the old man said.  He was holding his g...          82
# 32  "Can I go out to get sardines for you for tomo...          52
# 33  "No.  Go and play baseball.  I can still row a...          77
# 34  "I would like to go.  If I cannot fish with yo...          84
# 35  "You bought me a beer," the old man said.  "Yo...          67
# 36  "How old was I when you first took me in a boat?"          49
# 37  "Five and you nearly were killed when I brough...         128
# 38  "I can remember the tail slapping and banging ...         311
# 39  "I can remember the tail slapping and banging ...         311
# 40  "Can you really remember that or did I just te...          60
# 41  "I remember everything from when we first went...          57
# 42  The old man looked at him with his sun-burned,...          69
# 43  "If you were my boy I'd take you out and gambl...         134
# 44  "May I get the sardines?  I know where I can g...          65
# 45  "I have mine left from today.  I put them in s...          62
# 46                      "Let me get four fresh ones."          29
# 47  "One," the old man said.  His hope and his con...         124
# 48                               "Two," the boy said.          20
# 49  "Two," the old man agreed.  "You didn't steal ...          52
#
#     over_twitter_length  p_num  \
# 0                 False      0
# 1                 False      1
# 2                 False      2
# 3                 False      3
# 4                 False      4
# 5                 False      5
# 6                  True      6
# 7                  True      6
# 8                  True      6
# 9                  True      6
# 10                 True      7
# 11                 True      7
# 12                False      8
# 13                False      9
# 14                False     10
# 15                False     11
# 16                False     12
# 17                False     13
# 18                False     14
# 19                False     15
# 20                False     16
# 21                False     17
# 22                False     18
# 23                False     19
# 24                 True     20
# 25                 True     20
# 26                 True     20
# 27                 True     20
# 28                False     21
# 29                False     21
# 30                False     22
# 31                False     23
# 32                False     24
# 33                False     25
# 34                False     26
# 35                False     27
# 36                False     28
# 37                False     29
# 38                 True     30
# 39                 True     30
# 40                False     31
# 41                False     32
# 42                False     33
# 43                False     34
# 44                False     35
# 45                False     36
# 46                False     37
# 47                False     38
# 48                False     39
# 49                False     40
#
#                                          text_chunked  chunk_tot  chunk_num  \
# 0                                    ERNEST HEMINGWAY          1          1
# 1           CHARLES SCRIBNER'S SONS, NEW YORK\n\n1952          1          1
# 2   COPYRIGHT, 1952, BY\n\nERNEST HEMINGWAY\n\nPri...          1          1
# 3        TO CHARLIE SCRIBNER\n\nAND\n\nTO MAX PERKINS          1          1
# 4                                                              1          1
# 5                             THE OLD MAN AND THE SEA          1          1
# 6   He was an old man who fished alone in a skiff ...          4          1
# 7   parents had told him that the old man was now ...          4          2
# 8   the boy sad to see the old man come in each da...          4          3
# 9   patched with flour sacks and, furled, it looke...          4          4
# 10  The old man was thin and gaunt with deep wrink...          2          1
# 11  down the sides of his face and his hands had t...          2          2
# 12  Everything about him was old except his eyes a...          1          1
# 13  "Santiago," the boy said to him as they climbe...          1          1
# 14  The old man had taught the boy to fish and the...          1          1
# 15  "No," the old man said.  "You're with a lucky ...          1          1
# 16  "But remember how you went eighty-seven days w...          1          1
# 17  "I remember," the old man said.  "I know you d...          1          1
# 18  "It was papa made me leave.  I am a boy and I ...          1          1
# 19  "I know," the old man said.  "It is quite norm...          1          1
# 20                            "He hasn't much faith."          1          1
# 21  "No," the old man said.  "But we have.  Haven'...          1          1
# 22  "Yes," the boy said.  "Can I offer you a beer ...          1          1
# 23  "Why not?" the old man said.  "Between fisherm...          1          1
# 24  They sat on the Terrace and many of the fisher...          4          1
# 25  and the depths they had drifted their lines at...          4          2
# 26  length across two planks, with two men stagger...          4          3
# 27  shark factory on the other side of the cove wh...          4          4
# 28  When the wind was in the east a smell came acr...          2          1
# 29                          and sunny on the Terrace.          2          2
# 30                          "Santiago," the boy said.          1          1
# 31  "Yes," the old man said.  He was holding his g...          1          1
# 32  "Can I go out to get sardines for you for tomo...          1          1
# 33  "No.  Go and play baseball.  I can still row a...          1          1
# 34  "I would like to go.  If I cannot fish with yo...          1          1
# 35  "You bought me a beer," the old man said.  "Yo...          1          1
# 36  "How old was I when you first took me in a boat?"          1          1
# 37  "Five and you nearly were killed when I brough...          1          1
# 38  "I can remember the tail slapping and banging ...          2          1
# 39  noise of you clubbing him like chopping a tree...          2          2
# 40  "Can you really remember that or did I just te...          1          1
# 41  "I remember everything from when we first went...          1          1
# 42  The old man looked at him with his sun-burned,...          1          1
# 43  "If you were my boy I'd take you out and gambl...          1          1
# 44  "May I get the sardines?  I know where I can g...          1          1
# 45  "I have mine left from today.  I put them in s...          1          1
# 46                      "Let me get four fresh ones."          1          1
# 47  "One," the old man said.  His hope and his con...          1          1
# 48                               "Two," the boy said.          1          1
# 49  "Two," the old man agreed.  "You didn't steal ...          1          1
#
#                                         text_to_tweet  \
# 0                     ERNEST HEMINGWAY \n\n#hemingway
# 1   CHARLES SCRIBNER'S SONS, NEW YORK\n\n1952 \n\n...
# 2   COPYRIGHT, 1952, BY\n\nERNEST HEMINGWAY\n\nPri...
# 3   TO CHARLIE SCRIBNER\n\nAND\n\nTO MAX PERKINS \...
# 4                                      \n\n#hemingway
# 5              THE OLD MAN AND THE SEA \n\n#hemingway
# 6   He was an old man who fished alone in a skiff ...
# 7   parents had told him that the old man was now ...
# 8   the boy sad to see the old man come in each da...
# 9   patched with flour sacks and, furled, it looke...
# 10  The old man was thin and gaunt with deep wrink...
# 11  down the sides of his face and his hands had t...
# 12  Everything about him was old except his eyes a...
# 13  "Santiago," the boy said to him as they climbe...
# 14  The old man had taught the boy to fish and the...
# 15  "No," the old man said.  "You're with a lucky ...
# 16  "But remember how you went eighty-seven days w...
# 17  "I remember," the old man said.  "I know you d...
# 18  "It was papa made me leave.  I am a boy and I ...
# 19  "I know," the old man said.  "It is quite norm...
# 20             "He hasn't much faith." \n\n#hemingway
# 21  "No," the old man said.  "But we have.  Haven'...
# 22  "Yes," the boy said.  "Can I offer you a beer ...
# 23  "Why not?" the old man said.  "Between fisherm...
# 24  They sat on the Terrace and many of the fisher...
# 25  and the depths they had drifted their lines at...
# 26  length across two planks, with two men stagger...
# 27  shark factory on the other side of the cove wh...
# 28  When the wind was in the east a smell came acr...
# 29           and sunny on the Terrace. 2/2 #hemingway
# 30           "Santiago," the boy said. \n\n#hemingway
# 31  "Yes," the old man said.  He was holding his g...
# 32  "Can I go out to get sardines for you for tomo...
# 33  "No.  Go and play baseball.  I can still row a...
# 34  "I would like to go.  If I cannot fish with yo...
# 35  "You bought me a beer," the old man said.  "Yo...
# 36  "How old was I when you first took me in a boa...
# 37  "Five and you nearly were killed when I brough...
# 38  "I can remember the tail slapping and banging ...
# 39  noise of you clubbing him like chopping a tree...
# 40  "Can you really remember that or did I just te...
# 41  "I remember everything from when we first went...
# 42  The old man looked at him with his sun-burned,...
# 43  "If you were my boy I'd take you out and gambl...
# 44  "May I get the sardines?  I know where I can g...
# 45  "I have mine left from today.  I put them in s...
# 46       "Let me get four fresh ones." \n\n#hemingway
# 47  "One," the old man said.  His hope and his con...
# 48                "Two," the boy said. \n\n#hemingway
# 49  "Two," the old man agreed.  "You didn't steal ...
#
#     text_to_tweet_char_count tweeted_timestamp
# 0                         29
# 1                         52
# 2                        216
# 3                         53
# 4                         13
# 5                         36
# 6                        234
# 7                        232
# 8                        232
# 9                         97
# 10                       233
# 11                       208
# 12                       131
# 13                       159
# 14                        74
# 15                        82
# 16                       126
# 17                        96
# 18                        74
# 19                        63
# 20                        36
# 21                        65
# 22                       110
# 23                        63
# 24                       237
# 25                       231
# 26                       233
# 27                       219
# 28                       237
# 29                        40
# 30                        38
# 31                        95
# 32                        65
# 33                        90
# 34                        97
# 35                        80
# 36                        62
# 37                       141
# 38                       233
# 39                       106
# 40                        73
# 41                        70
# 42                        82
# 43                       147
# 44                        78
# 45                        75
# 46                        42
# 47                       137
# 48                        33
# 49                        65
